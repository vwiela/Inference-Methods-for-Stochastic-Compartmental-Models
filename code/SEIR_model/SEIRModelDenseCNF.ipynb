# %%
import cnfcomp
import numpy as np
import pandas as pd
import os 
os.chdir("../../")
basefolder = "./code/"
resultsfolder = "./output/"
figuresfolder = "./figures/"

# %%
seir2v_prior_full_dict = cnfcomp.seir2v_prior_full_wrap()
seir2v_prior_reparam_dict = cnfcomp.seir2v_prior_reparam_wrap()

config_seir2v_dense_1_1 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_1_1.csv', 'dense_1_1')
config_seir2v_dense_1_2 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_1_2.csv', 'dense_1_2')
config_seir2v_dense_2_1 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_2_1.csv', 'dense_2_1')
config_seir2v_dense_2_2 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_2_2.csv', 'dense_2_2')
config_seir2v_dense_3_1 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_3_1.csv', 'dense_3_1')
config_seir2v_dense_3_2 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_3_2.csv', 'dense_3_2')
config_seir2v_dense_4_1 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_4_1.csv', 'dense_4_1')
config_seir2v_dense_4_2 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_4_2.csv', 'dense_4_2')

# %%
cnfcomp.train_validate_infer(config_seir2v_dense_1_1, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_1_1_paper/", "full_normal_dense_1_1_paper", observationtype = "normal", summary_dim = 12, epochs = 100)
cnfcomp.train_validate_infer(config_seir2v_dense_1_2, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/eir2v_full_normal_dense_1_2_paper/", "full_normal_dense_1_2_paper", observationtype = "normal", summary_dim = 12, epochs = 100)
cnfcomp.train_validate_infer(config_seir2v_dense_2_1, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_2_1_paper/", "full_normal_dense_2_1_paper", observationtype = "normal", summary_dim = 12, epochs = 100)
cnfcomp.train_validate_infer(config_seir2v_dense_2_2, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_2_2_paper/", "full_normal_dense_2_2_paper", observationtype = "normal", summary_dim = 12, epochs = 100)
cnfcomp.train_validate_infer(config_seir2v_dense_3_1, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_3_1_paper/", "full_normal_dense_3_1_paper", observationtype = "normal", summary_dim = 12, epochs = 100)
cnfcomp.train_validate_infer(config_seir2v_dense_3_2, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_3_2_paper/", "full_normal_dense_3_2_paper", observationtype = "normal", summary_dim = 12, epochs = 100)

cnfcomp.train_validate_infer(config_seir2v_dense_1_1, seir2v_prior_reparam_dict, resultsfolder + "SimulationRuns/seir2v_reparam_normal_dense_1_1_paper/", "reparam_normal_dense_1_1_paper", observationtype = "normal", summary_dim = 10, epochs = 100)
cnfcomp.train_validate_infer(config_seir2v_dense_1_2, seir2v_prior_reparam_dict, resultsfolder + "SimulationRuns/seir2v_reparam_normal_dense_1_2_paper/", "reparam_normal_dense_1_2_paper", observationtype = "normal", summary_dim = 10, epochs = 100)

# %%
from cnfcomp import plot_input
from cnfcomp import plot_posteriors_2d3

n = 10000

postsamples_nf_seir2v_full_dense_1_1 =  np.array(pd.read_csv(resultsfolder + "Bayesflow_100epoch/" + "posterior_seir2v_full_normal_dense_1_1.csv", sep=","))[0:n,]
postsamples_nf_seir2v_full_dense_1_2 =  np.array(pd.read_csv(resultsfolder + "Bayesflow_100epoch/" + "posterior_seir2v_full_normal_dense_1_2.csv", sep=","))[0:n,]
postsamples_nf_seir2v_full_dense_2_1 =  np.array(pd.read_csv(resultsfolder + "Bayesflow_100epoch/" + "posterior_seir2v_full_normal_dense_2_1.csv", sep=","))[0:n,]
postsamples_nf_seir2v_full_dense_2_2 =  np.array(pd.read_csv(resultsfolder + "Bayesflow_100epoch/" + "posterior_seir2v_full_normal_dense_2_2.csv", sep=","))[0:n,]
postsamples_nf_seir2v_full_dense_3_1 =  np.array(pd.read_csv(resultsfolder + "Bayesflow_100epoch/" + "posterior_seir2v_full_normal_dense_3_1.csv", sep=","))[0:n,]
postsamples_nf_seir2v_full_dense_3_2 =  np.array(pd.read_csv(resultsfolder + "Bayesflow_100epoch/" + "posterior_seir2v_full_normal_dense_3_2.csv", sep=","))[0:n,]
postsamples_nf_seir2v_reparam_dense_1_1 =  np.array(pd.read_csv(resultsfolder + "Bayesflow_100epoch/" + "posterior_seir2v_reparam_normal_dense_1_1.csv", sep=","))[0:n,]
postsamples_nf_seir2v_reparam_dense_1_2 =  np.array(pd.read_csv(resultsfolder + "Bayesflow_100epoch/" + "posterior_seir2v_reparam_normal_dense_1_2.csv", sep=","))[0:n,]

postsamples_pf_seir2v_full_dense_1_1 =  np.array(pd.read_csv(resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_1_1.csv", sep=","))[0:n,]
postsamples_pf_seir2v_full_dense_1_2 =  np.array(pd.read_csv(resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_1_2.csv", sep=","))[0:n,]
postsamples_pf_seir2v_full_dense_2_1 =  np.array(pd.read_csv(resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_2_1.csv", sep=","))[0:n,]
postsamples_pf_seir2v_full_dense_2_2 =  np.array(pd.read_csv(resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_2_2.csv", sep=","))[0:n,]
postsamples_pf_seir2v_full_dense_3_1 =  np.array(pd.read_csv(resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_3_1.csv", sep=","))[0:n,]
postsamples_pf_seir2v_full_dense_3_2 =  np.array(pd.read_csv(resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_3_2.csv", sep=","))[0:n,]
postsamples_pf_seir2v_reparam_dense_1_1 =  np.array(pd.read_csv(resultsfolder + "ParticleFilter/" + "posterior_seir2v_reparam_normal_dense_1_1.csv", sep=","))[0:n,]
postsamples_pf_seir2v_reparam_dense_1_2 =  np.array(pd.read_csv(resultsfolder + "ParticleFilter/" + "posterior_seir2v_reparam_normal_dense_1_2.csv", sep=","))[0:n,]

true_params_1 = np.array([17, 5, 0.08, 3, 150, 500])
true_params_2 = np.array([11.7, 8.4, 0.23, 1.6, 222, 560])
true_params_3 = np.array([8, 3, 0.2, 4.2, 359, 915])
true_params_reparam_1 = np.array([1.36, 22, 51, 150, 500])

input_seir2v_full_dense_1_1 = plot_input(postsamples_nf_seir2v_full_dense_1_1, postsamples_pf_seir2v_full_dense_1_1, config_seir2v_dense_1_1, "normal", 
                                         ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"], "full_dense_1_1", true_params_1)

f = plot_posteriors_2d3(input_seir2v_full_dense_1_1)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_1_1.svg", format="svg", transparent=True)
print("Dense_1_1 Done!")

input_seir2v_full_dense_1_2 = plot_input(postsamples_nf_seir2v_full_dense_1_2, postsamples_pf_seir2v_full_dense_1_2, config_seir2v_dense_1_2, "normal", 
                                         ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"], "full_dense_1_2", true_params_1)
f = plot_posteriors_2d3(input_seir2v_full_dense_1_2)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_1_2.svg", format="svg", transparent=True)
print("Dense_1_2 Done!")

input_seir2v_full_dense_2_1 = plot_input(postsamples_nf_seir2v_full_dense_2_1, postsamples_pf_seir2v_full_dense_2_1, config_seir2v_dense_2_1, "normal", 
                                         ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"], "full_dense_2_1", true_params_2)
f = plot_posteriors_2d3(input_seir2v_full_dense_2_1)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_2_1.svg", format="svg", transparent=True)
print("Dense_2_1 Done!")

input_seir2v_full_dense_2_2 = plot_input(postsamples_nf_seir2v_full_dense_2_2, postsamples_pf_seir2v_full_dense_2_2, config_seir2v_dense_2_2, "normal", 
                                         ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"], "full_dense_2_2", true_params_2)
f = plot_posteriors_2d3(input_seir2v_full_dense_2_2)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_2_2.svg", format="svg", transparent=True)
print("Dense_2_2 Done!")

input_seir2v_full_dense_3_1 = plot_input(postsamples_nf_seir2v_full_dense_3_1, postsamples_pf_seir2v_full_dense_3_1, config_seir2v_dense_3_1, "normal", 
                                         ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"], "full_dense_3_1", true_params_3)
f = plot_posteriors_2d3(input_seir2v_full_dense_3_1)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_3_1.svg", format="svg", transparent=True)
print("Dense_3_1 Done!")

input_seir2v_full_dense_3_2 = plot_input(postsamples_nf_seir2v_full_dense_3_2, postsamples_pf_seir2v_full_dense_3_2, config_seir2v_dense_3_2, "normal", 
                                         ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"], "full_dense_3_2", true_params_3)
f = plot_posteriors_2d3(input_seir2v_full_dense_3_2)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_3_2.svg", format="svg", transparent=True)
print("Dense_3_2 Done!")

input_seir2v_reparam_dense_1_1 = plot_input(postsamples_nf_seir2v_reparam_dense_1_1, postsamples_pf_seir2v_reparam_dense_1_1, config_seir2v_dense_1_1, "normal", 
                                         ["$r_{0}$", "$e_{0}$", "$s_{0}$", "$t_{var}$", "$I_0$"], "reparam_dense_1_1", true_params_reparam_1)

f = plot_posteriors_2d3(input_seir2v_reparam_dense_1_1)
f.savefig(figuresfolder + "trajectories_seir2v_reparam_dense_1_1.svg", format="svg", transparent=True)
print("Reparam Dense_1_1 Done!")

input_seir2v_reparam_dense_1_2 = plot_input(postsamples_nf_seir2v_reparam_dense_1_2, postsamples_pf_seir2v_reparam_dense_1_2, config_seir2v_dense_1_2, "normal", 
                                         ["$r_{0}$", "$e_{0}$", "$s_{0}$", "$t_{var}$", "$I_0$"], "reparam_dense_1_1", true_params_reparam_1)

f = plot_posteriors_2d3(input_seir2v_reparam_dense_1_2)
f.savefig(figuresfolder + "trajectories_seir2v_reparam_dense_1_2.svg", format="svg", transparent=True)
print("Reparam Dense_1_2 Done!")
