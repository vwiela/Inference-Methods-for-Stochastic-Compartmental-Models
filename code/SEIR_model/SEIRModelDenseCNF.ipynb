# %%
import cnfcomp
import numpy as np
import pandas as pd
import os 
os.chdir("../../")
basefolder = "./code/"
resultsfolder = "./output/"
figuresfolder = "./figures/"

# %%
seir2v_prior_full_dict = cnfcomp.seir2v_prior_full_wrap()
seir2v_prior_reparam_dict = cnfcomp.seir2v_prior_reparam_wrap()

config_seir2v_dense_1_1 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_1_1.csv', 'dense_1_1')
config_seir2v_dense_1_2 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_1_2.csv', 'dense_1_2')
config_seir2v_dense_2_1 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_2_1.csv', 'dense_2_1')
config_seir2v_dense_2_2 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_2_2.csv', 'dense_2_2')
config_seir2v_dense_3_1 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_3_1.csv', 'dense_3_1')
config_seir2v_dense_3_2 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_3_2.csv', 'dense_3_2')
config_seir2v_dense_4_1 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_4_1.csv', 'dense_4_1')
config_seir2v_dense_4_2 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_4_2.csv', 'dense_4_2')

# %%
cnfcomp.train_validate_infer(config_seir2v_dense_1_1, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_1_1_paper/", "full_normal_dense_1_1_paper", summary_dim = 14)
cnfcomp.train_validate_infer(config_seir2v_dense_1_2, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_1_2_paper/", "full_normal_dense_1_2_paper", summary_dim = 14)
cnfcomp.train_validate_infer(config_seir2v_dense_2_1, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_2_1_paper/", "full_normal_dense_2_1_paper", summary_dim = 14)
cnfcomp.train_validate_infer(config_seir2v_dense_2_2, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_2_2_paper/", "full_normal_dense_2_2_paper", summary_dim = 14)
cnfcomp.train_validate_infer(config_seir2v_dense_3_1, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_3_1_paper/", "full_normal_dense_3_1_paper", summary_dim = 14)
cnfcomp.train_validate_infer(config_seir2v_dense_3_2, seir2v_prior_full_dict, resultsfolder + "SimulationRuns/seir2v_full_normal_dense_3_2_paper/", "full_normal_dense_3_2_paper", summary_dim = 14)

cnfcomp.train_validate_infer(config_seir2v_dense_1_1, seir2v_prior_reparam_dict, resultsfolder + "SimulationRuns/seir2v_reparam_normal_dense_1_1_paper/", "reparam_normal_dense_1_1_paper", summary_dim = 12)
cnfcomp.train_validate_infer(config_seir2v_dense_1_2, seir2v_prior_reparam_dict, resultsfolder + "SimulationRuns/seir2v_reparam_normal_dense_1_2_paper/", "reparam_normal_dense_1_2_paper", summary_dim = 12)

# %%
from cnfcomp import input_result_plot
from cnfcomp import plot_results
from cnfcomp import plot_histograms

postsamples_nf_seir2v_full_dense_1_1 = np.array(
    pd.read_csv(
        resultsfolder + "Bayesflow_100epoch/" + "posterior_full_normal_dense_1_1_paper.csv", sep=","
    )
)
postsamples_nf_seir2v_full_dense_1_2 = np.array(
    pd.read_csv(
        resultsfolder + "Bayesflow_100epoch/" + "posterior_full_normal_dense_1_2_paper.csv", sep=","
    )
)
postsamples_nf_seir2v_full_dense_2_1 = np.array(
    pd.read_csv(
        resultsfolder + "Bayesflow_100epoch/" + "posterior_full_normal_dense_2_1_paper.csv", sep=","
    )
)
postsamples_nf_seir2v_full_dense_2_2 = np.array(
    pd.read_csv(
        resultsfolder + "Bayesflow_100epoch/" + "posterior_full_normal_dense_2_2_paper.csv", sep=","
    )
)
postsamples_nf_seir2v_full_dense_3_1 = np.array(
    pd.read_csv(
        resultsfolder + "Bayesflow_100epoch/" + "posterior_full_normal_dense_3_1_paper.csv", sep=","
    )
)
postsamples_nf_seir2v_full_dense_3_2 = np.array(
    pd.read_csv(
        resultsfolder + "Bayesflow_100epoch/" + "posterior_full_normal_dense_3_2_paper.csv", sep=","
    )
)
postsamples_nf_seir2v_reparam_dense_1_1 = np.array(
    pd.read_csv(
        resultsfolder + "Bayesflow_100epoch/" + "posterior_reparam_normal_dense_1_1_paper.csv",
        sep=",",
    )
)
postsamples_nf_seir2v_reparam_dense_1_2 = np.array(
    pd.read_csv(
        resultsfolder + "Bayesflow_100epoch/" + "posterior_reparam_normal_dense_1_2_paper.csv",
        sep=",",
    )
)

postsamples_pf_seir2v_full_dense_1_1 = np.array(
    pd.read_csv(
        resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_1_1.csv", sep=","
    )
)
postsamples_pf_seir2v_full_dense_1_2 = np.array(
    pd.read_csv(
        resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_1_2.csv", sep=","
    )
)
postsamples_pf_seir2v_full_dense_2_1 = np.array(
    pd.read_csv(
        resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_2_1.csv", sep=","
    )
)
postsamples_pf_seir2v_full_dense_2_2 = np.array(
    pd.read_csv(
        resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_2_2.csv", sep=","
    )
)
postsamples_pf_seir2v_full_dense_3_1 = np.array(
    pd.read_csv(
        resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_3_1.csv", sep=","
    )
)
postsamples_pf_seir2v_full_dense_3_2 = np.array(
    pd.read_csv(
        resultsfolder + "ParticleFilter/" + "posterior_seir2v_full_normal_dense_3_2.csv", sep=","
    )
)
postsamples_pf_seir2v_reparam_dense_1_1 = np.array(
    pd.read_csv(
        resultsfolder + "ParticleFilter/" + "posterior_seir2v_reparam_normal_dense_1_1.csv", sep=","
    )
)
postsamples_pf_seir2v_reparam_dense_1_2 = np.array(
    pd.read_csv(
        resultsfolder + "ParticleFilter/" + "posterior_seir2v_reparam_normal_dense_1_2.csv", sep=","
    )
)


prior_samples = np.array(pd.read_csv(resultsfolder + "prior_test.csv", sep=","))[0:n,]


prior_values = seir2v_prior_full_dict["prior"].__call__(10000)["prior_draws"]

true_params_1 = np.array([17, 5, 0.08, 3, 150, 500])
true_params_2 = np.array([11.7, 8.4, 0.23, 1.6, 222, 560])
true_params_3 = np.array([8, 3, 0.2, 4.2, 359, 915])
true_params_reparam_1 = np.array([1.36, 22, 51, 150, 500])

input_seir2v_full_dense_1_1 = input_result_plot(
    postsamples_nf_seir2v_full_dense_1_1,
    postsamples_pf_seir2v_full_dense_1_1,
    config_seir2v_dense_1_1,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_dense_1_2",
    true_params_1,
)
f = plot_results(
    input_seir2v_full_dense_1_1,
    lower_b=np.array([9, 0, 0.05, 2, 120, 350]),
    upper_b=np.array([20, 12, 0.14, 5, 180, 600]),
)

f.savefig(figuresfolder + "trajectories_seir2v_full_dense_1_1.pdf")
print("Dense_1_1 Done!")


input_seir2v_full_dense_1_2 = input_result_plot(
    postsamples_nf_seir2v_full_dense_1_2,
    postsamples_pf_seir2v_full_dense_1_2,
    config_seir2v_dense_1_2,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_dense_1_2",
    true_params_1,
)
f = plot_results(
    input_seir2v_full_dense_1_2,
    lower_b=np.array([10, 0, 0.05, 2, 120, 250]),
    upper_b=np.array([20, 12, 0.13, 5, 190, 550]),
)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_1_2.pdf")
print("Dense_1_2 Done!")


input_seir2v_full_dense_2_1 = input_result_plot(
    postsamples_nf_seir2v_full_dense_2_1,
    postsamples_pf_seir2v_full_dense_2_1,
    config_seir2v_dense_2_1,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_dense_2_1",
    true_params_2,
)
f = plot_results(
    input_seir2v_full_dense_2_1,
    lower_b=np.array([7, 4, 0.15, 1, 217, 380]),
    upper_b=np.array([16, 13, 0.35, 2.5, 230, 720]),
)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_2_1.pdf")
print("Dense_2_1 Done!")

input_seir2v_full_dense_2_2 = input_result_plot(
    postsamples_nf_seir2v_full_dense_2_2,
    postsamples_pf_seir2v_full_dense_2_2,
    config_seir2v_dense_2_2,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_dense_2_2",
    true_params_2,
)
f = plot_results(
    input_seir2v_full_dense_2_2,
    lower_b=np.array([12, 3, 0.15, 1.1, 215, 400]),
    upper_b=np.array([17.5, 8, 0.23, 1.5, 230, 700]),
)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_2_2.pdf")
print("Dense_2_2 Done!")

input_seir2v_full_dense_3_1 = input_result_plot(
    postsamples_nf_seir2v_full_dense_3_1,
    postsamples_pf_seir2v_full_dense_3_1,
    config_seir2v_dense_3_1,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_dense_3_1",
    true_params_3,
)
f = plot_results(
    input_seir2v_full_dense_3_1,
    lower_b=np.array([3, 1.8, 0.1, 2.4, 356, 750]),
    upper_b=np.array([10, 8, 0.45, 9, 361, 1050]),
)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_3_1.pdf")
print("Dense_3_1 Done!")

input_seir2v_full_dense_3_2 = input_result_plot(
    postsamples_nf_seir2v_full_dense_3_2,
    postsamples_pf_seir2v_full_dense_3_2,
    config_seir2v_dense_3_2,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_dense_3_2",
    true_params_3,
)
f = plot_results(
    input_seir2v_full_dense_3_2,
    lower_b=np.array([3.5, 0, 0.1, 2.5, 357, 600]),
    upper_b=np.array([11, 6, 0.32, 7.5, 361, 1050]),
)
f.savefig(figuresfolder + "trajectories_seir2v_full_dense_3_2.pdf")
print("Dense_3_2 Done!")

input_seir2v_reparam_dense_1_1 = input_result_plot(
    postsamples_nf_seir2v_reparam_dense_1_1,
    postsamples_pf_seir2v_reparam_dense_1_1,
    config_seir2v_dense_1_1,
    "normal",
    ["$r_{0}$", "$e_{0}$", "$s_{0}$", "$t_{var}$", "$I_0$"],
    "reparam_dense_1_1",
    true_params_reparam_1,
)

f = plot_results(
    input_seir2v_reparam_dense_1_1,
    lower_b=np.array([1.28, 17.5, 47, 120, 340]),
    upper_b=np.array([1.4, 24, 54, 180, 600]),
)
f.savefig(figuresfolder + "trajectories_seir2v_reparam_dense_1_1.pdf")
print("Reparam Dense_1_1 Done!")

input_seir2v_reparam_dense_1_2 = input_result_plot(
    postsamples_nf_seir2v_reparam_dense_1_2,
    postsamples_pf_seir2v_reparam_dense_1_2,
    config_seir2v_dense_1_2,
    "normal",
    ["$r_{0}$", "$e_{0}$", "$s_{0}$", "$t_{var}$", "$I_0$"],
    "reparam_dense_1_1",
    true_params_reparam_1,
)

f = plot_results(
    input_seir2v_reparam_dense_1_2,
    lower_b=np.array([1.28, 17.5, 45, 130, 260]),
    upper_b=np.array([1.4, 24, 52, 190, 500]),
)
f.savefig(figuresfolder + "trajectories_seir2v_reparam_dense_1_2.pdf")
print("Reparam Dense_1_2 Done!")

print("Done!")
