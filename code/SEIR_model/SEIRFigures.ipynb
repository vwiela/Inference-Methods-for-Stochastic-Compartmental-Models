# %%
import cnfcomp
from cnfcomp import input_result_plot
from cnfcomp import plot_results
from cnfcomp import plot_histograms
import numpy as np
import pandas as pd

# %%
seir2v_prior_full_dict = cnfcomp.seir2v_prior_full_wrap()

config_seir2v_dense_1_1 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_1_1.csv', 'dense_1_1')
config_seir2v_dense_1_2 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_1_2.csv', 'dense_1_2')
config_seir2v_dense_2_1 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_2_1.csv', 'dense_2_1')
config_seir2v_dense_2_2 = cnfcomp.load_data_dense('./data/seir2v_synth_dense_binomial_and_normal_2_2.csv', 'dense_2_2')

config_seir2v_sparse_1_1_1 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_1_1.csv', 'sparse_1_1_1')
config_seir2v_sparse_1_1_2 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_1_2.csv', 'sparse_1_1_2')
config_seir2v_sparse_1_1_3 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_1_3.csv', 'sparse_1_1_3')
config_seir2v_sparse_1_2_1 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_1_1.csv', 'sparse_1_2_1')
config_seir2v_sparse_1_2_2 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_2_2.csv', 'sparse_1_2_2')
config_seir2v_sparse_1_2_3 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_2_3.csv', 'sparse_1_2_3')

config_seir2v_real_ethiopia = cnfcomp.load_data_sparse('./data/seir2v_real_ethiopia.csv', 'ethiopia')

# %%
folder_cnf = "./output/CNF_Experiments/" 
folder_pf = "./output/PNF_Experiments/"

postsamples_cnf_seir2v_full_dense_1_1 = np.array(pd.read_csv(folder_cnf + "seir2v_full_dense_1_1/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_full_dense_1_2 = np.array(pd.read_csv(folder_cnf + "seir2v_full_dense_1_2/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_full_dense_2_1 = np.array(pd.read_csv(folder_cnf + "seir2v_full_dense_2_1/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_full_dense_2_2 = np.array(pd.read_csv(folder_cnf + "seir2v_full_dense_2_2/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_full_sparse_1_1_1 = np.array(pd.read_csv(folder_cnf + "seir2v_full_sparse_1_1_1/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_full_sparse_1_1_2 = np.array(pd.read_csv(folder_cnf + "seir2v_full_sparse_1_1_2/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_full_sparse_1_1_3 = np.array(pd.read_csv(folder_cnf + "seir2v_full_sparse_1_1_3/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_full_sparse_1_2_1 = np.array(pd.read_csv(folder_cnf + "seir2v_full_sparse_1_2_1/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_full_sparse_1_2_2 = np.array(pd.read_csv(folder_cnf + "seir2v_full_sparse_1_2_2/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_full_sparse_1_2_3 = np.array(pd.read_csv(folder_cnf + "seir2v_full_sparse_1_2_3/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_reparam_dense_1_1 = np.array(pd.read_csv(folder_cnf + "seir2v_reparam_dense_1_1/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_reparam_dense_1_2 = np.array(pd.read_csv(folder_cnf + "seir2v_reparam_dense_1_2/posterior_samples.csv", sep=","))
postsamples_cnf_seir2v_full_real_ethiopia = np.array(pd.read_csv(folder_cnf + "seir2v_full_real_ethiopia/posterior_samples.csv", sep=","))

postsamples_pf_seir2v_full_dense_1_1 = np.array(pd.read_csv(folder_pf + "seir2v_full_dense_1_1/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_full_dense_1_2 = np.array(pd.read_csv(folder_pf + "seir2v_full_dense_1_2/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_full_dense_2_1 = np.array(pd.read_csv(folder_pf + "seir2v_full_dense_2_1/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_full_dense_2_2 = np.array(pd.read_csv(folder_pf + "seir2v_full_dense_2_2/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_full_sparse_1_1_1 = np.array(pd.read_csv(folder_pf + "seir2v_full_sparse_1_1_1/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_full_sparse_1_1_2 = np.array(pd.read_csv(folder_pf + "seir2v_full_sparse_1_1_2/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_full_sparse_1_1_3 = np.array(pd.read_csv(folder_pf + "seir2v_full_sparse_1_1_3/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_full_sparse_1_2_1 = np.array(pd.read_csv(folder_pf + "seir2v_full_sparse_1_2_1/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_full_sparse_1_2_2 = np.array(pd.read_csv(folder_pf + "seir2v_full_sparse_1_2_2/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_full_sparse_1_2_3 = np.array(pd.read_csv(folder_pf + "seir2v_full_sparse_1_2_3/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_reparam_dense_1_1 = np.array(pd.read_csv(folder_pf + "seir2v_reparam_dense_1_1/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_reparam_dense_1_2 = np.array(pd.read_csv(folder_pf + "seir2v_reparam_dense_1_2/posterior_samples.csv", sep=","))
postsamples_pf_seir2v_full_real_ethiopia = np.array(pd.read_csv(folder_pf + "seir2v_full_real_ethiopia/posterior_samples.csv", sep=","))

prior_values = seir2v_prior_full_dict["prior"].__call__(10000)["prior_draws"]

true_params_1 = np.array([17, 5, 0.08, 3, 150, 500])
true_params_2 = np.array([11.7, 8.4, 0.23, 1.6, 222, 560])
true_params_reparam_1 = np.array([1.36, 22, 51, 150, 500])
pub_params = np.array([16.7, 5, 0.08, 2.3, 184.5, 635])

# %%
input_seir2v_full_dense_1_1 = input_result_plot(
    postsamples_cnf_seir2v_full_dense_1_1,
    postsamples_pf_seir2v_full_dense_1_1,
    config_seir2v_dense_1_1,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_dense_1_2",
    true_params_1,
)
f = plot_results(
    input_seir2v_full_dense_1_1,
    lower_b=np.array([9, 0, 0.05, 2, 120, 350]),
    upper_b=np.array([20, 12, 0.14, 5, 180, 600]),
)

f.savefig("./figures/comparison_seir2v_full_dense_1_1.pdf")
print("Dense_1_1 Done!")

input_seir2v_full_dense_1_2 = input_result_plot(
    postsamples_cnf_seir2v_full_dense_1_2,
    postsamples_pf_seir2v_full_dense_1_2,
    config_seir2v_dense_1_2,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_dense_1_2",
    true_params_1,
)
f = plot_results(
    input_seir2v_full_dense_1_2,
    lower_b=np.array([10, 0, 0.05, 2, 120, 250]),
    upper_b=np.array([20, 12, 0.13, 5, 190, 550]),
)
f.savefig("./figures/comparison_seir2v_full_dense_1_2.pdf")
print("Dense_1_2 Done!")


input_seir2v_full_dense_2_1 = input_result_plot(
    postsamples_cnf_seir2v_full_dense_2_1,
    postsamples_pf_seir2v_full_dense_2_1,
    config_seir2v_dense_2_1,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_dense_2_1",
    true_params_2,
)
f = plot_results(
    input_seir2v_full_dense_2_1,
    lower_b=np.array([7, 4, 0.15, 1, 217, 380]),
    upper_b=np.array([16, 13, 0.35, 2.5, 230, 720]),
)
f.savefig("./figures/comparison_seir2v_full_dense_2_1.pdf")
print("Dense_2_1 Done!")

input_seir2v_full_dense_2_2 = input_result_plot(
    postsamples_cnf_seir2v_full_dense_2_2,
    postsamples_pf_seir2v_full_dense_2_2,
    config_seir2v_dense_2_2,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_dense_2_2",
    true_params_2,
)
f = plot_results(
    input_seir2v_full_dense_2_2,
    lower_b=np.array([12, 3, 0.15, 1.1, 215, 400]),
    upper_b=np.array([17.5, 8, 0.23, 1.5, 230, 700]),
)
f.savefig("./figures/comparison_seir2v_full_dense_2_2.pdf")
print("Dense_2_2 Done!")

input_seir2v_reparam_dense_1_1 = input_result_plot(
    postsamples_cnf_seir2v_reparam_dense_1_1,
    postsamples_pf_seir2v_reparam_dense_1_1,
    config_seir2v_dense_1_1,
    "normal",
    ["$r_{0}$", "$e_{0}$", "$s_{0}$", "$t_{var}$", "$I_0$"],
    "reparam_dense_1_1",
    true_params_reparam_1,
)

f = plot_histograms(prior_values, postsamples_cnf_seir2v_full_dense_1_1, postsamples_pf_seir2v_full_dense_1_1, ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"])
f.savefig("./figures/histogram_seir2v_full_dense_1_1.pdf", bbox_inches="tight")
print("Histogram Dense_1_1 Done!")

# %%
input_seir2v_full_sparse_1_1_1 = input_result_plot(
    postsamples_cnf_seir2v_full_sparse_1_1_1,
    postsamples_pf_seir2v_full_sparse_1_1_1,
    config_seir2v_sparse_1_1_1,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_sparse_1_1_1",
    true_params_1,
)
f = plot_results(
    input_seir2v_full_sparse_1_1_1,
    lower_b=np.array([7, 0, 0.05, 2.0, 120, 160]),
    upper_b=np.array([21, 13, 0.15, 5, 210, 650]),
)
f.savefig("./figures/comparison_seir2v_full_sparse_1_1_1.pdf")
print("sparse_1_1_1 Done!")

input_seir2v_full_sparse_1_1_2 = input_result_plot(
    postsamples_cnf_seir2v_full_sparse_1_1_2,
    postsamples_pf_seir2v_full_sparse_1_1_2,
    config_seir2v_sparse_1_1_2,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_sparse_1_1_2",
    true_params_1,
)
f = plot_results(
    input_seir2v_full_sparse_1_1_2,
    lower_b=np.array([7, 0, 0.04, 1.2, 100, 150]),
    upper_b=np.array([29, 14, 0.15, 5, 300, 900]),
)
f.savefig("./figures/comparison_seir2v_full_sparse_1_1_2.pdf")
print("sparse_1_1_2 Done!")


input_seir2v_full_sparse_1_1_3 = input_result_plot(
    postsamples_cnf_seir2v_full_sparse_1_1_3,
    postsamples_pf_seir2v_full_sparse_1_1_3,
    config_seir2v_sparse_1_1_3,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_sparse_1_1_3",
    true_params_1,
)
f = plot_results(
    input_seir2v_full_sparse_1_1_3,
    lower_b=np.array([6, 0, 0.05, 2.3, 120, 180]),
    upper_b=np.array([20, 15, 0.2, 7.5, 230, 750]),
)
f.savefig("./figures/comparison_seir2v_full_sparse_1_1_3.pdf")
print("sparse_1_1_3 Done!")

input_seir2v_full_sparse_1_2_1 = input_result_plot(
    postsamples_cnf_seir2v_full_sparse_1_2_1,
    postsamples_pf_seir2v_full_sparse_1_2_1,
    config_seir2v_sparse_1_2_1,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_sparse_1_2_1",
    true_params_1,
)
f = plot_results(
    input_seir2v_full_sparse_1_2_1,
    lower_b=np.array([9, 0, 0.05, 2.1, 120, 150]),
    upper_b=np.array([21, 13, 0.15, 5, 210, 600]),
)
f.savefig("./figures/comparison_seir2v_full_sparse_1_2_1.pdf")
print("sparse_1_2_1 Done!")


input_seir2v_full_sparse_1_2_2 = input_result_plot(
    postsamples_cnf_seir2v_full_sparse_1_2_2,
    postsamples_pf_seir2v_full_sparse_1_2_2,
    config_seir2v_sparse_1_2_2,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_sparse_1_2_2",
    true_params_1,
)
f = plot_results(
    input_seir2v_full_sparse_1_2_2,
    lower_b=np.array([8, 0, 0.05, 2.0, 119, 180]),
    upper_b=np.array([21, 12, 0.15, 5.2, 200, 600]),
)
f.savefig("./figures/comparison_seir2v_full_sparse_1_2_2.pdf")
print("sparse_1_2_2 Done!")

input_seir2v_full_sparse_1_2_3 = input_result_plot(
    postsamples_cnf_seir2v_full_sparse_1_2_3,
    postsamples_pf_seir2v_full_sparse_1_2_3,
    config_seir2v_sparse_1_2_3,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_sparse_1_2_3",
    true_params_1,
)
f = plot_results(
    input_seir2v_full_sparse_1_2_3,
    lower_b=np.array([9, 0, 0.05, 1.6, 119, 160]),
    upper_b=np.array([25, 13, 0.15, 5, 210, 700]),
)
f.savefig("./figures/comparison_seir2v_full_sparse_1_2_3.pdf")
print("sparse_1_2_3 Done!")

# %%
f = plot_results(
    input_seir2v_reparam_dense_1_1,
    lower_b=np.array([1.28, 17.5, 47, 120, 340]),
    upper_b=np.array([1.4, 24, 54, 180, 600]),
)
f.savefig("./figures/comparison_seir2v_reparam_dense_1_1.pdf")
print("Reparam Dense_1_1 Done!")

input_seir2v_reparam_dense_1_2 = input_result_plot(
    postsamples_cnf_seir2v_reparam_dense_1_2,
    postsamples_pf_seir2v_reparam_dense_1_2,
    config_seir2v_dense_1_2,
    "normal",
    ["$r_{0}$", "$e_{0}$", "$s_{0}$", "$t_{var}$", "$I_0$"],
    "reparam_dense_1_1",
    true_params_reparam_1,
)

f = plot_results(
    input_seir2v_reparam_dense_1_2,
    lower_b=np.array([1.28, 17.5, 45, 130, 260]),
    upper_b=np.array([1.4, 24, 52, 190, 500]),
)
f.savefig("./figures/comparison_seir2v_reparam_dense_1_2.pdf")
print("Reparam Dense_1_2 Done!")

# %%
input_seir2v_full_real_ethiopia = input_result_plot(
    postsamples_cnf_seir2v_full_real_ethiopia,
    postsamples_pf_seir2v_full_real_ethiopia,
    config_seir2v_real_ethiopia,
    "normal",
    ["$\\gamma^{-1}$", "$\\kappa^{-1}$", "$\\beta$", "$s$", "$t_{var}$", "$I_0$"],
    "full_real_ethiopia",
    pub_params,
    paramstring="Pub. Param.",
)
f = plot_results(
    input_seir2v_full_real_ethiopia,
    lower_b=np.array([5, 0, 0.0, 1, 119, 180]),
    upper_b=np.array([26, 14, 0.18, 6.2, 300, 1050]),
    errorbars=True,
)
f.savefig("./figures/comparison_seir2v_full_real_ethiopia.pdf")
