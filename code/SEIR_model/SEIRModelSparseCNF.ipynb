# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, parent_dir)

import cnfcomp

os.chdir("../../")

# %%
seir2v_prior_full_dict = cnfcomp.seir2v_prior_full_wrap()

config_seir2v_sparse_1_1_1 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_1_1.csv', 'sparse_1_1_1')
config_seir2v_sparse_1_1_2 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_1_2.csv', 'sparse_1_1_2')
config_seir2v_sparse_1_1_3 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_1_3.csv', 'sparse_1_1_3')
config_seir2v_sparse_1_2_1 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_1_1.csv', 'sparse_1_2_1')
config_seir2v_sparse_1_2_2 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_2_2.csv', 'sparse_1_2_2')
config_seir2v_sparse_1_2_3 = cnfcomp.load_data_sparse('./data/seir2v_synth_sparse_1_2_3.csv', 'sparse_1_2_3')

config_seir2v_real_ethiopia = cnfcomp.load_data_sparse('./data/seir2v_real_ethiopia.csv', 'real_ethiopia')

# %%
cnfcomp.train_validate_infer(config_seir2v_sparse_1_1_1, seir2v_prior_full_dict, "./output/CNF_Experiments/seir2v_full_sparse_1_1_1/", "full_sparse_1_1_1", summary_dim = 14)
cnfcomp.train_validate_infer(config_seir2v_sparse_1_1_2, seir2v_prior_full_dict, "./output/CNF_Experiments/seir2v_full_sparse_1_1_2/", "full_sparse_1_1_2", summary_dim = 14)
cnfcomp.train_validate_infer(config_seir2v_sparse_1_1_3, seir2v_prior_full_dict, "./output/CNF_Experiments/seir2v_full_sparse_1_1_3/", "full_sparse_1_1_3", summary_dim = 14)
cnfcomp.train_validate_infer(config_seir2v_sparse_1_2_1, seir2v_prior_full_dict, "./output/CNF_Experiments/seir2v_full_sparse_1_2_1/", "full_sparse_1_2_1", summary_dim = 14)
cnfcomp.train_validate_infer(config_seir2v_sparse_1_2_2, seir2v_prior_full_dict, "./output/CNF_Experiments/seir2v_full_sparse_1_2_2/", "full_sparse_1_2_2", summary_dim = 14)
cnfcomp.train_validate_infer(config_seir2v_sparse_1_2_3, seir2v_prior_full_dict, "./output/CNF_Experiments/seir2v_full_sparse_1_2_3/", "full_sparse_1_2_3", summary_dim = 14)

cnfcomp.train_validate_infer(config_seir2v_real_ethiopia, seir2v_prior_full_dict, "./output/CNF_Experiments/seir2v_full_real_ethiopia/", "full_real_ethiopia", summary_dim = 14)
